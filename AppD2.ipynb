# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
l=pd.read_csv('C:\\Users\\MRUH\\Desktop\\App-dev-main\\loan21.csv')
l
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes          3  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0           0             360.0
# ...

# %%
l.shape
# Out:
# (367, 12)

# %%
l.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
def Gender(x):
    if x=='Male':
        return 1
    if x=='Female':
        return 2
def Married(x):
    if x=='Yes':
        return 0
    if x=='No':
        return 1
def Self_Employed(x):
    if x=='Yes':
        return 0
    if x=='No':
        return 1
def Education(x):
    if x=='Graduate':
        return 0
    if x=='Not Graduate':
        return 1
def Dependents(x):
    if x=='3+':
        return 3
    elif x=='1':
        return 1
    else:
        return 2
def Property_Area(x):
    if x=='Urban':
        return 0
    if x=='Semiurban':
        return 1
    if x=='Rural':
        return 2

# %%
l['Gender']=l['Gender'].apply(Gender)
l['Married']=l['Married'].apply(Married)
l['Education']=l['Education'].apply(Education)
l['Self_Employed']=l['Self_Employed'].apply(Self_Employed)
l['Dependents']=l['Dependents'].apply(Dependents)
l['Property_Area']=l['Property_Area'].apply(Property_Area)

# %%
l
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001015     1.0        0           2          0            1.0
# 1    LP001022     1.0        0           1          0            1.0
# 2    LP001031     1.0        0           2          0            1.0
# 3    LP001035     1.0        0           2          0            1.0
# 4    LP001051     1.0        1           2          1            1.0
# ..        ...     ...      ...         ...        ...            ...
# 362  LP002971     1.0        0           2          1            0.0
# 363  LP002975     1.0        0           2          0            1.0
# 364  LP002980     1.0        1           2          0            1.0
# 365  LP002986     1.0        0           2          0            1.0
# 366  LP002989     1.0        1           2          0            0.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model= LogisticRegression()

# %%
import math
med=math.floor(l.Gender.median())
med1=math.floor(l.Self_Employed.median())
med2=math.floor(l.Credit_History.median())
mea=math.floor(l.LoanAmount.mean())
mea1=math.floor(l.Loan_Amount_Term.mean())
l.Gender=l.Gender.fillna(med)
l.Self_Employed=l.Self_Employed.fillna(med1)
l.LoanAmount=l.LoanAmount.fillna(mea)
l.Loan_Amount_Term =l.Loan_Amount_Term .fillna(mea1)
l.Credit_History =l.Credit_History .fillna(med2)

# %%
x=l.drop(['LoanAmount','Loan_ID'],axis='columns')

# %%
y=l.LoanAmount

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.3)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[1,0,2,1,1,5720,0,180,2,1]])
# Out:
# array([0], dtype=int64)

# %%
model.predict([[0,1,2,0,0,5,1,190,1,0]])
# Out:
# array([0], dtype=int64)

# %%
import pickle
pickle.dump(model, open("reg.pkl", "wb"))

# %%
model = pickle.load(open("reg.pkl", "rb"))
model
# Out:
# LogisticRegression()

# %%
model.predict([[1,0,2,1,1,5720,0,180,2,1]])
# Out:
# array([0], dtype=int64)
